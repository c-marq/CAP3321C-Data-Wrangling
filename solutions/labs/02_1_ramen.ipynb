# %% [markdown]
# <a href="https://colab.research.google.com/github/c-marq/CAP3321C-Data-Wrangling/blob/main/solutions/labs/02_1_ramen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2-1: Analyze the ramen data

# %%
#  https://www.kaggle.com/residentmario/ramen-ratings
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Tasks

# %%
# 1
data = pd.read_csv('ramen-ratings.csv')

# %%
# 2
data.head()

# %%
# 3
data.tail()

# %%
# 4
data.describe()

# %%
# 5
data.nunique()

# %%
# 6
data.query('Country == "Vietnam"')

# %%
# 7
data[['Brand','Style']]

# %%
# 8
data.Country

# %%
# 9
data.sort_values('Stars', ascending=False)

# %%
# 10
data.Country.replace('USA','United States', inplace=True)
data.head()

# %% [markdown]
# ## Questions

# %%
# 1
data.Country.nunique()

# %%
# 2
data['Stars'] = pd.to_numeric(data['Stars'], errors='coerce')
data.groupby('Country')['Stars'].mean().sort_values(ascending=False).head(3)

# %%
# 3
data.groupby('Country')['Stars'].mean().sort_values().head(3)

# %%
# 4
data.groupby('Country').count()[['Brand']].sort_values('Brand', ascending=False).head(3)
