# %% [markdown]
# <a href="https://colab.research.google.com/github/c-marq/CAP3321C-Data-Wrangling/blob/main/solutions/labs/02_3_exams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2-3: Analyze the exam data

# %%
import pandas as pd

# %% [markdown]
# ## Tasks

# %%
# 1
data = pd.read_csv('exams.csv')
data.head()

# %%
# 2
data.info()

# %%
# 3
data.describe()

# %%
# 4
data.groupby('race/ethnicity').mean(numeric_only=True)

# %%
# 5
data[['gender']]

# %%
# 6
data['gender']

# %%
# 7
data.gender

# %%
# 8
data.query('gender == "female" and `math score` >= 90')

# %% [markdown]
# ## Questions

# %%
# 1
data.groupby('test preparation course').mean(numeric_only=True)

# %%
# 2
data.groupby('gender')[['math score']].mean()

# %%
# 3
data['total score'] = data['math score'] + data['reading score'] + data['writing score']
data.groupby('gender')[['total score']].mean()

# %%
# 4
data.groupby('parental level of education').mean(numeric_only=True).sort_values(by=['math score','reading score','writing score'], ascending=False)
