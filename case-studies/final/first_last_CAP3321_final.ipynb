# %% [markdown]
# <a href="https://colab.research.google.com/github/c-marq/CAP3321C-Data-Wrangling/blob/main/case-studies/final/first_last_CAP3321_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Project: Case Study Analysis
#
# | | |
# |---|---|
# | **Case Study Selected:** | *(Airports / Laptops / Medical Costs)* |
# | **Section Completed:** | *(Section 1 / Section 2)* |
# | **Student Name:** | *(Your full name)* |
# | **Partner Name:** | *(Partner's full name)* |
# | **Course:** | CAP3321C — Data Wrangling with Python |
# | **Instructor:** | *(Instructor name)* |
# | **Term:** | *(e.g., Spring 2026)* |
# | **Due Date:** | *(MM/DD/YYYY)* |

# %% [markdown]
# ---
# ## Setup
# Import the libraries you will need and load your dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Update the filename below to match your chosen case study:
#   Airports:      'tsa_claims1.csv'  (Section 1)  /  'tsa_claims2.csv'  (Section 2)
#   Laptops:       'laptops.csv'
#   Medical Costs: 'insurance.csv'

df = pd.read_csv('your_file_here.csv')
df.head()

# %% [markdown]
# ---
# ## Data Exploration
# Explore the structure of your dataset. How many rows and columns are there? What are the data types? Are there missing values?

# %%
# Shape of the dataset
print(f'Rows: {df.shape[0]}  |  Columns: {df.shape[1]}')
print()

# Data types
print(df.dtypes)
print()

# Missing values
print(df.isnull().sum())

# %% [markdown]
# ### Observations
# *Write your observations about the dataset structure here. What did you notice? What will need to be cleaned or transformed before you begin your analysis?*

# %% [markdown]
# ---
# ## Data Cleaning
# Clean the data and explain why you cleaned it the way you did.

# %%
# Perform your data cleaning steps here.
# Examples:
#   - Drop or fill missing values
#   - Convert data types (e.g., dates, numeric columns)
#   - Remove duplicates
#   - Rename columns for clarity

# %% [markdown]
# ### Cleaning Summary
# *Explain the cleaning steps you performed and why. What decisions did you make about missing data, data types, or outliers?*

# %% [markdown]
# ---
# ## Question 1
# *Replace this text with the first question from your chosen case study.*

# %%
# Your analysis for Question 1

# %% [markdown]
# ### Results
# *Summarize what your table or plot tells you about this question.*

# %% [markdown]
# ---
# ## Question 2
# *Replace this text with the second question from your chosen case study.*

# %%
# Your analysis for Question 2

# %% [markdown]
# ### Results
# *Summarize what your table or plot tells you about this question.*

# %% [markdown]
# ---
# ## Question 3
# *Replace this text with the next question from your chosen case study. Add additional Question sections as needed by duplicating this pattern of cells.*

# %%
# Your analysis for Question 3

# %% [markdown]
# ### Results
# *Summarize what your table or plot tells you about this question.*

# %% [markdown]
# ---
# ## Conclusion
# *Provide a brief overall summary of your findings. What were the most interesting or surprising insights from your analysis?*
